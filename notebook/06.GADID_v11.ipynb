# %% [markdown]
# # GADID_v11 Notebook
#
# > **All outputs are organised under a single project folder.**
# > Set `PROJECT_NAME` in **Cell 2 — Configuration** before running anything else.
# > Every CSV, chart and comparison file lands in:
# > `data/processed/<PROJECT_NAME>/csv/` and `data/processed/<PROJECT_NAME>/charts/`
#
# | Cell | Operation |
# |------|-----------|
# | **1** | Install & Imports |
# | **2** | ⚙ **Configuration — set `PROJECT_NAME` here** |
# | **3** | All helper functions (run once) |
# | **4** | ▶ Step 1 — Add `filename` column to source CSV |
# | **5a** | ▶ Step 2a — Generate CSV from **local** image directory |
# | **5b** | ▶ Step 2b — Generate CSV from **Wasabi bucket** (S3) |
# | **6** | ▶ Step 3 — Compare both CSVs (stats + lists + charts) |
# | **A** | Appendix — Re-run comparison from saved CSVs |
# | **7** | ▶ Dataset Analysis — config (Train / Val CSVs) |
# | **8** | ▶ Dataset Analysis — run (stats + charts) |

# %% [markdown]
# ## 1 — Install & Imports

# %%
# %pip install pandas matplotlib seaborn tqdm boto3 python-dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import warnings
from pathlib import Path

import boto3
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from botocore.config import Config
from botocore.exceptions import ClientError
from tqdm import tqdm

try:
    from dotenv import load_dotenv
    load_dotenv(Path("..") / ".env", override=True)
    print("✓ .env loaded")
except Exception:
    pass

warnings.filterwarnings("ignore")
pd.set_option("display.max_colwidth", 80)
pd.set_option("display.max_rows", 30)

print(f"pandas  {pd.__version__}")
print("✓ imports ready")
# Out:
# ✓ .env loaded
# pandas  3.0.2
# ✓ imports ready

# %% [markdown]
# ## 2 — Configuration

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  PROJECT — set this before running any other cell                       ║
# ╚══════════════════════════════════════════════════════════════════════════╝
PROJECT_NAME = "GAID-v11"   # ← change to your project name

# ── Root processed directory ───────────────────────────────────────────────
PROCESSED_ROOT = Path("/home/taiaburrahman/dataset_manager_pro/data/processed")

# ── Project sub-directories (auto-derived — do not edit) ──────────────────
PROJECT_DIR = PROCESSED_ROOT / PROJECT_NAME
CSV_DIR     = PROJECT_DIR / "csv"
CHARTS_DIR  = PROJECT_DIR / "charts"

for _d in [CSV_DIR, CHARTS_DIR]:
    _d.mkdir(parents=True, exist_ok=True)

# Alias kept for backward-compat (helper functions still use OUTPUT_DIR)
OUTPUT_DIR = CSV_DIR

# ── Source CSVs ────────────────────────────────────────────────────────────
SOURCE_CSV = "/home/taiaburrahman/dataset_manager_pro/data/projects/GAID/07.csv/GAID_Dataset_v9_full_Train.csv"
VAL_CSV    = "/home/taiaburrahman/dataset_manager_pro/data/projects/GAID/07.csv/GAID_Dataset_v9_full_Val.csv"

# ── Local image directory to scan (Step 2a) ────────────────────────────────
# Extracted dataset from Wasabi zip files — change if your extraction path differs
IMAGE_SCAN_DIR = "/home/taiaburrahman/dataset_manager_pro/data/processed/v11_samples"
NEW_DATASET_DIR = "/home/taiaburrahman/dataset_manager_pro/data/processed/v11"

# ── Wasabi config (Step 2b) ────────────────────────────────────────────────
# Reads from .env automatically; override here if needed.
WASABI_ACCESS_KEY_ID     = os.getenv("WASABI_ACCESS_KEY_ID",     "")
WASABI_SECRET_ACCESS_KEY = os.getenv("WASABI_SECRET_ACCESS_KEY", "")
WASABI_BUCKET            = os.getenv("WASABI_BUCKET",            "")
WASABI_REGION            = os.getenv("WASABI_REGION",            "us-east-1")
WASABI_ENDPOINT          = os.getenv("WASABI_ENDPOINT",          "https://s3.wasabisys.com")

# S3 prefix to scan in the bucket (Step 2b)
WASABI_SCAN_PREFIX = "datasets/gen_ai_detector_dataset/"

# ── Label mapping ──────────────────────────────────────────────────────────
# key-path / folder-name substring → integer label  (0 = fake, 1 = real)
LABEL_MAP = {
    # Any folder whose name starts with these → fake (0)
    "gen":                   0,   # Gen_samples_*, gen_ai_detector_dataset, genai, ...
    "ai":                    0,   # ai_image_x_collection, ai_*, ...
    "genai":                 0,
    "ai_image_x_collection": 0,
    # Real imagery
    "human":                 1,
    "real":                  1,
}

# ── File extensions to include when scanning locally ───────────────────────
# Only image formats — archives are not included since we scan extracted data
IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tiff", ".tif"}

# ── Summary ────────────────────────────────────────────────────────────────
print(f"┌─ Project ────────────────────────────────────────────────────────┐")
print(f"│  Name      : {PROJECT_NAME:<51}│")
print(f"│  Root      : {str(PROJECT_DIR):<51}│")
print(f"│  CSV dir   : {str(CSV_DIR):<51}│")
print(f"│  Charts    : {str(CHARTS_DIR):<51}│")
print(f"├─ Inputs ─────────────────────────────────────────────────────────┤")
print(f"│  Source CSV: {SOURCE_CSV[-51:]:<51}│")
print(f"│  Wasabi    : {WASABI_BUCKET}/{WASABI_SCAN_PREFIX}"[:67] + "│")
print(f"└──────────────────────────────────────────────────────────────────┘")
# Out:
# ┌─ Project ────────────────────────────────────────────────────────┐
# │  Name      : GAID-v11                                           │
# │  Root      : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11│
# │  CSV dir   : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv│
# │  Charts    : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/charts│
# ├─ Inputs ─────────────────────────────────────────────────────────┤
# │  Source CSV: projects/GAID/07.csv/GAID_Dataset_v9_full_Train.csv│
# │  Wasabi    : bbvision/datasets/gen_ai_detector_dataset/│
# └──────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 3 — Helper Functions

# %%
# ══════════════════════════════════════════════════════════════════════════════
# HELPERS
# ══════════════════════════════════════════════════════════════════════════════

def _proj() -> str:
    """Return the current PROJECT_NAME global (safe default if not set)."""
    return globals().get("PROJECT_NAME", "default_project")

def _csv_dir() -> Path:
    return globals().get("CSV_DIR", Path("./processed/csv"))

def _charts_dir() -> Path:
    return globals().get("CHARTS_DIR", Path("./processed/charts"))

def _box(lines: list[str], width: int = 72) -> str:
    sep = "─" * (width - 2)
    def row(s): return f"║  {s:<{width-4}}║"
    out = [f"╔{sep}╗"]
    for l in lines:
        out.append(f"╠{sep}╣" if l == "---" else row(l))
    out.append(f"╚{sep}╝")
    return "\n".join(out)

def _pfx(p: str) -> str:
    """Convert a step prefix like '01' → '01.' (empty string → no prefix)."""
    return f"{p}." if p else ""

def _infer_label(top_folder: str) -> int | None:
    """Map a top-level subfolder name to a label using LABEL_MAP prefixes."""
    key = top_folder.lower()
    for lmap_prefix, label in LABEL_MAP.items():
        if key.startswith(lmap_prefix):
            return label
    return None


def _rel_name(path_str: str) -> str:
    """Return 'parent_folder/filename' from a full path for robust matching."""
    p = Path(str(path_str))
    return f"{p.parent.name}/{p.name}"


# ── Step 1 ─────────────────────────────────────────────────────────────────

def add_filename_column(
    source_csv:  str | Path,
    output_dir:  str | Path | None = None,
    path_col:    str = "image_path",
    output_name: str | None = None,
    prefix:      str = "01",
) -> pd.DataFrame:
    """
    Load *source_csv*, extract 'parent_folder/basename' from *path_col*,
    add it as 'filename', and save to *output_dir* (defaults to project CSV_DIR).
    *prefix* is prepended to the output filename, e.g. '01.name.csv'.
    """
    src = Path(source_csv)
    out = Path(output_dir) if output_dir else _csv_dir()
    out.mkdir(parents=True, exist_ok=True)

    print(f"Loading {src.name} …")
    df = pd.read_csv(src, dtype=str, low_memory=False)

    if path_col not in df.columns:
        raise ValueError(f"Column '{path_col}' not found. Available: {list(df.columns)}")

    df["filename"] = df[path_col].apply(_rel_name)

    stem = output_name or (src.stem + "_with_filename")
    dest = out / (_pfx(prefix) + stem + ".csv")
    df.to_csv(dest, index=False)

    print(df[[path_col, "filename"]].head(5).to_string(index=False))
    print(_box([
        f"STEP 1 — ADD FILENAME COLUMN  [project: {_proj()}]", "---",
        f"Source          : {src.name}",
        f"Saved to        : {dest}",
        "---",
        f"Rows            : {len(df):,}",
        f"Columns         : {list(df.columns)}",
        f"Unique filenames : {df['filename'].nunique():,}",
    ]))
    return df


# ── Step 2 ─────────────────────────────────────────────────────────────────

def scan_image_dir(
    scan_dir:    str | Path,
    output_dir:  str | Path | None = None,
    output_name: str = "scanned_images",
    prefix:      str = "02",
) -> pd.DataFrame:
    """
    Walk *scan_dir* recursively, collect image files, build a DataFrame
    with columns (image_path, labels, directory, filename), and save to
    *output_dir* (defaults to project CSV_DIR).
    Labels are inferred from the top-level subfolder name using LABEL_MAP.
    *prefix* is prepended to the output filename, e.g. '02.name.csv'.
    """
    root = Path(scan_dir)
    out  = Path(output_dir) if output_dir else _csv_dir()
    out.mkdir(parents=True, exist_ok=True)

    print(f"Scanning {root} …")
    records = []

    if not root.exists():
        raise FileNotFoundError(f"scan_dir does not exist: {root}")

    top_folders = sorted([d for d in root.iterdir() if d.is_dir()])
    print(f"  Sub-folders : {[d.name for d in top_folders]}")

    # Fallback: no sub-folders → treat *root* itself as the single "top" so
    # images that sit directly under scan_dir (or under deeper nested dirs
    # without an obvious top-level split) are still collected.
    if not top_folders:
        print(f"  No sub-folders found — scanning {root.name} directly.\n")
        top_folders = [root]
    else:
        print()

    for top in top_folders:
        label = _infer_label(top.name)
        files = [f for f in top.rglob("*")
                 if f.is_file() and f.suffix.lower() in IMAGE_EXTS]

        if not files:
            print(f"  (no images under {top.name})")
            continue

        # Group files by their first 3 folder levels relative to *root*
        # so progress bars read like "<top>/<sub>/<sub>".
        groups: dict[str, list[Path]] = {}
        for f in files:
            parent_parts = f.parent.relative_to(root).parts
            key = "/".join(parent_parts[:3]) if parent_parts else top.name
            groups.setdefault(key, []).append(f)

        for key in sorted(groups):
            for f in tqdm(groups[key], desc=f"  {key}", leave=True):
                records.append({
                    "image_path": str(f),
                    "labels":     label,
                    "directory":  top.name,
                    "filename":   f"{f.parent.name}/{f.name}",
                })

    # Guarantee expected columns even when no images were found, so downstream
    # code (and the summary box below) never raises KeyError.
    df = pd.DataFrame(
        records,
        columns=["image_path", "labels", "directory", "filename"],
    )
    dest = out / (_pfx(prefix) + output_name + ".csv")
    df.to_csv(dest, index=False)

    if df.empty:
        label_counts: dict = {}
        unique_fn = 0
    else:
        label_counts = df["labels"].value_counts(dropna=False).to_dict()
        unique_fn = df["filename"].nunique()

    print(_box([
        f"STEP 2a — SCAN LOCAL DIR  [project: {_proj()}]", "---",
        f"Scanned         : {root}",
        f"Saved to        : {dest}",
        "---",
        f"Total images    : {len(df):,}",
        f"Label 0 (fake)  : {label_counts.get(0, 0):,}",
        f"Label 1 (real)  : {label_counts.get(1, 0):,}",
        f"Unknown label   : {label_counts.get(None, 0):,}",
        f"Unique filenames : {unique_fn:,}",
    ]))
    return df


# ── Step 3 ─────────────────────────────────────────────────────────────────

def compare_csvs(
    df_source:   pd.DataFrame | str | Path,
    df_scanned:  pd.DataFrame | str | Path,
    output_dir:  str | Path | None = None,
    charts_dir:  str | Path | None = None,
    compare_col: str = "filename",
    prefix:      str = "03",
) -> dict:
    """
    Compare two DataFrames (or CSV paths) on *compare_col*.

    Returns a dict with:
      common          — filenames in both
      only_in_source  — filenames only in source CSV
      only_in_scanned — filenames only in scanned CSV

    Saves difference lists to CSVs and displays bar + pie charts.
    """
    out   = Path(output_dir)  if output_dir  else _csv_dir()
    c_dir = Path(charts_dir) if charts_dir  else _charts_dir()
    out.mkdir(parents=True, exist_ok=True)
    c_dir.mkdir(parents=True, exist_ok=True)

    if isinstance(df_source, (str, Path)):
        print(f"Loading source  CSV …")
        df_source  = pd.read_csv(df_source,  dtype=str, low_memory=False)
    if isinstance(df_scanned, (str, Path)):
        print(f"Loading scanned CSV …")
        df_scanned = pd.read_csv(df_scanned, dtype=str, low_memory=False)

    if compare_col not in df_source.columns:
        df_source  = df_source.copy()
        df_source[compare_col]  = df_source["image_path"].apply(_rel_name)
    if compare_col not in df_scanned.columns:
        df_scanned = df_scanned.copy()
        df_scanned[compare_col] = df_scanned["image_path"].apply(_rel_name)

    set_src = set(df_source[compare_col].dropna())
    set_scn = set(df_scanned[compare_col].dropna())

    common          = set_src & set_scn
    only_in_source  = set_src - set_scn
    only_in_scanned = set_scn - set_src

    # ── Save difference lists ──────────────────────────────────────────────
    fp = _pfx(prefix)
    def _save_list(names, tag):
        rows = df_source[df_source[compare_col].isin(names)] if "source" in tag \
               else df_scanned[df_scanned[compare_col].isin(names)]
        p = out / f"{fp}compare_{tag}.csv"
        rows.to_csv(p, index=False)
        return p

    p_common  = out / f"{fp}compare_common.csv"
    df_source[df_source[compare_col].isin(common)].to_csv(p_common, index=False)
    p_only_src = _save_list(only_in_source,  "only_in_source")
    p_only_scn = _save_list(only_in_scanned, "only_in_scanned")

    # ── Text summary ──────────────────────────────────────────────────────
    print(_box([
        f"STEP 3 — CSV COMPARISON  [project: {_proj()}]", "---",
        f"Compare column       : '{compare_col}'",
        "---",
        f"Source CSV           : {len(set_src):>10,} unique filenames",
        f"Scanned CSV          : {len(set_scn):>10,} unique filenames",
        "---",
        f"✓  Common (both)     : {len(common):>10,}",
        f"◀  Only in source    : {len(only_in_source):>10,}",
        f"▶  Only in scanned   : {len(only_in_scanned):>10,}",
        "---",
        f"CSV dir              : {out}",
        f"Charts dir           : {c_dir}",
        f"common CSV           : {p_common.name}",
        f"only_in_source CSV   : {p_only_src.name}",
        f"only_in_scanned CSV  : {p_only_scn.name}",
    ]))

    # ── Sample lists ──────────────────────────────────────────────────────
    print("\n── Sample: common files (first 10) ──")
    display(df_source[df_source[compare_col].isin(common)][[compare_col, "labels"]].head(10))

    print("\n── Sample: only in SOURCE csv (first 10) ──")
    display(df_source[df_source[compare_col].isin(only_in_source)][[compare_col, "labels"]].head(10))

    print("\n── Sample: only in SCANNED csv (first 10) ──")
    display(df_scanned[df_scanned[compare_col].isin(only_in_scanned)][[compare_col, "labels"]].head(10))

    # ── Charts ────────────────────────────────────────────────────────────
    _plot_comparison(
        len(common), len(only_in_source), len(only_in_scanned),
        len(set_src), len(set_scn),
        df_source, df_scanned, compare_col, common, c_dir,
        prefix=prefix,
    )

    return {
        "common":          common,
        "only_in_source":  only_in_source,
        "only_in_scanned": only_in_scanned,
    }


def _plot_comparison(
    n_common, n_only_src, n_only_scn,
    n_src_total, n_scn_total,
    df_source, df_scanned, compare_col,
    common_set, out_dir,
    prefix: str = "03",
):
    """Render and save 4 charts: bar overview, stacked bar per CSV,
       two donut pies (composition of each CSV)."""
    sns.set_theme(style="whitegrid", palette="muted")
    COLORS = {"common": "#4CAF50", "only_src": "#2196F3", "only_scn": "#FF9800"}

    fig, axes = plt.subplots(2, 2, figsize=(16, 11))
    fig.suptitle("CSV Comparison — Filename Overlap Analysis",
                 fontsize=15, fontweight="bold", y=1.01)

    # ── 1. Overview bar chart ─────────────────────────────────────────────
    ax = axes[0, 0]
    categories = ["Common\n(both)", "Only in\nSource CSV", "Only in\nScanned CSV"]
    counts     = [n_common, n_only_src, n_only_scn]
    colors     = [COLORS["common"], COLORS["only_src"], COLORS["only_scn"]]
    bars = ax.bar(categories, counts, color=colors, edgecolor="white", width=0.5)
    for bar, count in zip(bars, counts):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + max(counts) * 0.01,
                f"{count:,}", ha="center", va="bottom", fontsize=10, fontweight="bold")
    ax.set_title("Overview: Filename Overlap", fontsize=12, fontweight="bold")
    ax.set_ylabel("Number of Files")
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))

    # ── 2. Stacked bar per CSV ────────────────────────────────────────────
    ax = axes[0, 1]
    csv_names  = ["Source CSV", "Scanned CSV"]
    n_common_s = [n_common,   n_common]
    n_unique_s = [n_only_src, n_only_scn]
    b1 = ax.bar(csv_names, n_common_s, color=COLORS["common"],  label="Common",        edgecolor="white")
    b2 = ax.bar(csv_names, n_unique_s, bottom=n_common_s,
                color=[COLORS["only_src"], COLORS["only_scn"]], label="Unique to this", edgecolor="white")
    for bar, total in zip(b1, [n_src_total, n_scn_total]):
        ax.text(bar.get_x() + bar.get_width()/2, total + max(n_src_total, n_scn_total) * 0.01,
                f"Total\n{total:,}", ha="center", va="bottom", fontsize=9)
    ax.set_title("Per-CSV Composition", fontsize=12, fontweight="bold")
    ax.set_ylabel("Number of Files")
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
    ax.legend()

    # ── 3. Source CSV donut ───────────────────────────────────────────────
    ax = axes[1, 0]
    wedge_sizes = [n_common, n_only_src]
    wedge_labels = [f"Common\n{n_common:,}", f"Only in Source\n{n_only_src:,}"]
    wedge_colors = [COLORS["common"], COLORS["only_src"]]
    if sum(wedge_sizes) > 0:
        wedges, texts, autotexts = ax.pie(
            wedge_sizes, labels=wedge_labels, colors=wedge_colors,
            autopct="%1.1f%%", startangle=90,
            wedgeprops=dict(width=0.55, edgecolor="white"),
        )
        for t in autotexts: t.set_fontsize(9)
    ax.set_title(f"Source CSV  ({n_src_total:,} total)", fontsize=12, fontweight="bold")

    # ── 4. Scanned CSV donut ──────────────────────────────────────────────
    ax = axes[1, 1]
    wedge_sizes = [n_common, n_only_scn]
    wedge_labels = [f"Common\n{n_common:,}", f"Only in Scanned\n{n_only_scn:,}"]
    wedge_colors = [COLORS["common"], COLORS["only_scn"]]
    if sum(wedge_sizes) > 0:
        wedges, texts, autotexts = ax.pie(
            wedge_sizes, labels=wedge_labels, colors=wedge_colors,
            autopct="%1.1f%%", startangle=90,
            wedgeprops=dict(width=0.55, edgecolor="white"),
        )
        for t in autotexts: t.set_fontsize(9)
    ax.set_title(f"Scanned CSV  ({n_scn_total:,} total)", fontsize=12, fontweight="bold")

    plt.tight_layout()
    chart_path = out_dir / f"{_pfx(prefix)}compare_charts.png"
    plt.savefig(chart_path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"\n  Charts saved → {chart_path}")

    # ── 5. Label breakdown bar (common vs unique, per label) ──────────────
    if "labels" in df_source.columns and "labels" in df_scanned.columns:
        fig2, axes2 = plt.subplots(1, 2, figsize=(14, 5))
        fig2.suptitle("Label Distribution — Common vs Unique",
                      fontsize=13, fontweight="bold")

        for ax2, (df_, title) in zip(axes2,
                [(df_source, "Source CSV"), (df_scanned, "Scanned CSV")]):
            df_ = df_.copy()
            is_common = df_[compare_col].isin(common_set)
            df_["_group"] = is_common.map({True: "Common", False: "Unique"})
            # Normalise labels to str first to avoid mixed int/str duplicates
            df_["_label_str"] = df_["labels"].astype(str).map(
                {"0": "Fake (0)", "1": "Real (1)"}
            ).fillna("Unknown")
            grp = (
                df_.groupby(["_group", "_label_str"])
                   .size()
                   .reset_index(name="count")
            )
            # pivot_table handles any residual duplicates by summing
            pivot = grp.pivot_table(
                index="_label_str", columns="_group",
                values="count", aggfunc="sum", fill_value=0,
            )
            pivot.index.name = "Label"
            pivot.plot(kind="bar", ax=ax2, colormap="Set2", edgecolor="white", rot=0)
            ax2.set_title(title, fontsize=11, fontweight="bold")
            ax2.set_xlabel("Label")
            ax2.set_ylabel("Count")
            ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
            ax2.legend(title="Group")

        plt.tight_layout()
        chart2_path = out_dir / f"{_pfx(prefix)}compare_label_breakdown.png"
        plt.savefig(chart2_path, dpi=150, bbox_inches="tight")
        plt.show()
        print(f"  Label breakdown saved → {chart2_path}")


# ── Step 2b: Wasabi bucket scan ────────────────────────────────────────────

def _get_wasabi_client():
    """Build a boto3 S3 client from the config variables."""
    def _g(name, default=""):
        return globals().get(name) or os.getenv(name, default)
    return boto3.client(
        "s3",
        endpoint_url=_g("WASABI_ENDPOINT", "https://s3.wasabisys.com"),
        region_name=_g("WASABI_REGION", "us-east-1"),
        aws_access_key_id=_g("WASABI_ACCESS_KEY_ID"),
        aws_secret_access_key=_g("WASABI_SECRET_ACCESS_KEY"),
        config=Config(signature_version="s3v4",
                      retries={"max_attempts": 3, "mode": "adaptive"}),
    )


def _infer_label_from_key(key: str) -> int | None:
    """Infer label from any part of the S3 key using LABEL_MAP prefixes."""
    key_lower = key.lower()
    for substr, label in LABEL_MAP.items():
        if substr in key_lower:
            return label
    return None


def scan_wasabi_bucket(
    prefix:      str,
    output_dir:  str | Path | None = None,
    output_name: str = "wasabi_scanned",
    ext_filter:  set | None = None,
    max_keys:    int | None = None,
    file_prefix: str = "02",
) -> pd.DataFrame:
    """
    List all objects under *prefix* in the configured Wasabi bucket,
    build a DataFrame with columns (image_path, labels, directory, filename),
    and save it to *output_dir*.

    Parameters
    ----------
    prefix      : S3 key prefix to scan, e.g. 'datasets/gen_ai_detector_dataset_scaled_224/'
    output_dir  : Local directory to save the output CSV.
    output_name : Output CSV filename stem.
    ext_filter  : Set of lowercase extensions to keep (e.g. {'.jpg', '.png'}).
                  Pass None or empty set to include ALL objects.
    max_keys    : Stop after collecting this many rows (useful for quick tests).
    file_prefix : Numeric prefix for output filename, e.g. '02' → '02.name.csv'.
    """
    client = _get_wasabi_client()
    bucket = globals().get("WASABI_BUCKET") or os.getenv("WASABI_BUCKET", "")
    out    = Path(output_dir) if output_dir else _csv_dir()
    out.mkdir(parents=True, exist_ok=True)

    # Normalise prefix
    if prefix and not prefix.endswith("/"):
        prefix += "/"

    print(f"Scanning Wasabi bucket '{bucket}' — prefix: '{prefix}' …")

    paginator = client.get_paginator("list_objects_v2")
    records   = []
    page_num  = 0

    with tqdm(desc="Listing objects", unit=" obj", dynamic_ncols=True) as bar:
        for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
            page_num += 1
            for obj in page.get("Contents", []):
                key  = obj["Key"]
                name = Path(key).name

                # Skip folder placeholder objects (zero-byte, key ends with /)
                if not name or key.endswith("/"):
                    continue

                # Optional extension filter
                if ext_filter:
                    sfx = "".join(Path(name).suffixes).lower()   # handles .tar.lz4
                    if not any(sfx.endswith(e) for e in ext_filter):
                        continue

                # Infer top-level subdirectory relative to prefix
                rel       = key[len(prefix):]
                top_dir   = rel.split("/")[0] if "/" in rel else ""
                label     = _infer_label_from_key(key)

                parent_dir = Path(key).parent.name
                records.append({
                    "image_path":    f"s3://{bucket}/{key}",
                    "labels":        label,
                    "directory":     top_dir,
                    "filename":      f"{parent_dir}/{name}",
                    "s3_key":        key,
                    "size_bytes":    obj["Size"],
                    "last_modified": obj["LastModified"].isoformat(),
                })
                bar.update(1)

                if max_keys and len(records) >= max_keys:
                    break
            if max_keys and len(records) >= max_keys:
                break

    df   = pd.DataFrame(records)
    dest = out / (_pfx(file_prefix) + output_name + ".csv")
    df.to_csv(dest, index=False)

    label_counts = df["labels"].value_counts(dropna=False).to_dict()
    total_size   = df["size_bytes"].sum() if "size_bytes" in df.columns else 0
    tsize_str    = f"{total_size/1024**3:.2f} GB" if total_size > 1024**3 else \
                   f"{total_size/1024**2:.1f} MB"

    print(_box([
        f"STEP 2b — SCAN WASABI BUCKET  [project: {_proj()}]", "---",
        f"Bucket          : {bucket}",
        f"Prefix          : {prefix}",
        f"Saved to        : {dest}",
        "---",
        f"Total objects   : {len(df):,}",
        f"Total size      : {tsize_str}",
        f"Label 0 (fake)  : {label_counts.get(0, 0):,}",
        f"Label 1 (real)  : {label_counts.get(1, 0):,}",
        f"Unknown label   : {label_counts.get(None, 0):,}",
        f"Unique filenames : {df['filename'].nunique():,}",
    ]))
    return df


print("✓ All helpers loaded")
# Out:
# ✓ All helpers loaded

# %% [markdown]
# ## 4 — Step 1: Add `filename` Column to Source CSV
#
# Extracts `parent_folder/basename` from every row's `image_path` and saves the enriched CSV.

# %%
# Output → data/processed/<PROJECT_NAME>/csv/01.<stem>_with_filename.csv
df_source = add_filename_column(
    source_csv  = SOURCE_CSV,
    output_name = Path(SOURCE_CSV).stem + "_with_filename",
    prefix      = "01",
)
# Out:
# Loading GAID_Dataset_v9_full_Train.csv …
#                                                                                            image_path                                  filename
# /home/ubuntu/vision/data/NewDB/NewDB_Real/Shutterstock_Real/real/0e35d3c709ef4123bb7b8cff23c885a4.jpg real/0e35d3c709ef4123bb7b8cff23c885a4.jpg
#                          /home/ubuntu/vision/data/NewDB/NewDB_Real/tristanzhang32_Real/real/12905.jpg                            real/12905.jpg
#                               /home/ubuntu/vision/data/NewDB/NewDB_Fake/pixelpulse_1800/fake/1085.jpg                             fake/1085.jpg
#                                /home/ubuntu/vision/data/NewDB/NewDB_Real/ulid25k/real/image_05650.png                      real/image_05650.png
# /home/ubuntu/vision/data/NewDB/NewDB_Fake/Shutterstock_Fake/fake/d3c613a6d9574f55b3854643c5ca2374.jpg fake/d3c613a6d9574f55b3854643c5ca2374.jpg
# ╔──────────────────────────────────────────────────────────────────────╗
# ║  STEP 1 — ADD FILENAME COLUMN  [project: GAID-v11]                   ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Source          : GAID_Dataset_v9_full_Train.csv                    ║
# ║  Saved to        : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/01.GAID_Dataset_v9_full_Train_with_filename.csv║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Rows            : 704,779                                           ║
# ║  Columns         : ['image_path', 'labels', 'directory', 'filename'] ║
# ║  Unique filenames : 700,281                                          ║
# ╚──────────────────────────────────────────────────────────────────────╝

# %% [markdown]
# ## 5 — Step 2: Generate CSV from Scanned Image Directory
#
# Walks every subfolder in `IMAGE_SCAN_DIR`, collects all image files, infers labels from the top-level folder name, and writes a CSV with the same schema as the source.

# %%
# Output → data/processed/<PROJECT_NAME>/csv/02.<PROJECT_NAME>_local_scanned.csv
df_scanned = scan_image_dir(
    scan_dir    = IMAGE_SCAN_DIR,
    output_name = f"{PROJECT_NAME}_local_scanned",
    prefix      = "02",
)
# Out:
# Scanning /home/taiaburrahman/dataset_manager_pro/data/processed/v11_samples …
#   Sub-folders : ['Gen_samples_Gemini_100325', 'Gen_samples_Grok3_180325', 'gen_ai_detector_dataset']
#   Gen_samples_Gemini_100325/Gen_samples_Gemini_100325: 100%|██████████| 4055/4055 [00:00<00:00, 446518.84it/s]
#   Gen_samples_Grok3_180325: 100%|██████████| 12356/12356 [00:00<00:00, 543864.21it/s]
#   gen_ai_detector_dataset/PubDB_Fake/Shutterstock_Fake: 100%|██████████| 30646/30646 [00:00<00:00, 242592.11it/s]
#   gen_ai_detector_dataset/PubDB_Fake/ai_shoes: 100%|██████████| 1356/1356 [00:00<00:00, 413574.48it/s]
#   gen_ai_detector_dataset/PubDB_Fake/dalle_rec_Fake: 100%|██████████| 5780/5780 [00:00<00:00, 449820.52it/s]
#   gen_ai_detector_dataset/PubDB_Fake/pixelpulse_1800: 100%|██████████| 1868/1868 [00:00<00:00, 376789.45it/s]
#   gen_ai_detector_dataset/PubDB_Fake/tristanzhang32_Fake: 100%|██████████| 8698/8698 [00:00<00:00, 350253.52it/s]
#   gen_ai_detector_dataset/PubDB_Real/dalle_rec_Real: 100%|██████████| 3103/3103 [00:00<00:00, 336755.47it/s]
#   gen_ai_detector_dataset/PubDB_Real/environmental_scenes: 100%|██████████| 492/492 [00:00<00:00, 307999.64it/s]
#   gen_ai_detector_dataset/PubDB_Real/home: 100%|██████████| 33981/33981 [00:00<00:00, 329842.62it/s]
#   gen_ai_detector_dataset/PubDB_Real/mit_adobe_5k_Real: 100%|██████████| 9967/9967 [00:00<00:00, 452382.08it/s]
#   gen_ai_detector_dataset/PubDB_Real/pht30k_Real: 100%|██████████| 3312/3312 [00:00<00:00, 345139.88it/s]
#   gen_ai_detector_dataset/PubDB_Real/real_shoes: 100%|██████████| 825/825 [00:00<00:00, 362259.30it/s]
#   gen_ai_detector_dataset/PubDB_Real/tristanzhang32_Real: 100%|██████████| 14368/14368 [00:00<00:00, 428170.83it/s]
#   gen_ai_detector_dataset/PubDB_Real/ulid25k: 100%|██████████| 24976/24976 [00:00<00:00, 510255.27it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/ImageFX: 100%|██████████| 5209/5209 [00:00<00:00, 485373.77it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/adobeFirefly: 100%|██████████| 1146/1146 [00:00<00:00, 401593.48it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/bingimagecreator: 100%|██████████| 1208/1208 [00:00<00:00, 400784.63it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/dalle3: 100%|██████████| 15745/15745 [00:00<00:00, 483301.74it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/deepdream: 100%|██████████| 30/30 [00:00<00:00, 146312.93it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/flux: 100%|██████████| 7110/7110 [00:00<00:00, 423282.21it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/gemini: 100%|██████████| 233/233 [00:00<00:00, 299043.09it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/gork3: 100%|██████████| 41/41 [00:00<00:00, 105242.63it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/gork3_generated_deepfake_BB_ethinicity_march25: 100%|██████████| 510/510 [00:00<00:00, 405054.92it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/grok2: 100%|██████████| 2765/2765 [00:00<00:00, 396568.55it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/ideogram2: 100%|██████████| 475/475 [00:00<00:00, 359425.29it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/imagen3: 100%|██████████| 3964/3964 [00:00<00:00, 424755.92it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/leonardoai: 100%|██████████| 4110/4110 [00:00<00:00, 468058.36it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/midjourney: 100%|██████████| 26156/26156 [00:00<00:00, 497427.83it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/nightcafe: 100%|██████████| 68/68 [00:00<00:00, 231316.04it/s]
#   gen_ai_detector_dataset/ai_image_x_collection_feb25_cleaned/stabledIffusion: 100%|██████████| 256/256 [00:00<00:00, 333771.16it/s]
#   gen_ai_detector_dataset/genAI/genAI: 100%|██████████| 170072/170072 [00:00<00:00, 499652.70it/s]
#   gen_ai_detector_dataset/genAI_2/genAI_2: 100%|██████████| 104024/104024 [00:00<00:00, 531301.22it/s]
#   gen_ai_detector_dataset/genAI_3/genAI_3: 100%|██████████| 4845/4845 [00:00<00:00, 486111.45it/s]
#   gen_ai_detector_dataset/genAI_4/genAI_4: 100%|██████████| 858/858 [00:00<00:00, 468399.43it/s]
#   gen_ai_detector_dataset/genAI_5/genAI_5: 100%|██████████| 87/87 [00:00<00:00, 219425.40it/s]
#   gen_ai_detector_dataset/genAI_6: 100%|██████████| 525/525 [00:00<00:00, 400001.74it/s]
#   gen_ai_detector_dataset/human/human: 100%|██████████| 336016/336016 [00:00<00:00, 526858.67it/s]
#   gen_ai_detector_dataset/human_2/human_2: 100%|██████████| 18823/18823 [00:00<00:00, 499253.07it/s]
#   gen_ai_detector_dataset/human_3: 100%|██████████| 1274/1274 [00:00<00:00, 458870.18it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_Japanese-Actors: 100%|██████████| 187/187 [00:00<00:00, 304832.82it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_JapaneseCelebrities_: 100%|██████████| 1203/1203 [00:00<00:00, 461177.93it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_africanews.en_images: 100%|██████████| 205/205 [00:00<00:00, 338250.32it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_american_1996communitty: 100%|██████████| 795/795 [00:00<00:00, 374323.27it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_asian_Japan.PMO_: 100%|██████████| 282/282 [00:00<00:00, 368701.29it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_asian_SAdiaspora: 100%|██████████| 34/34 [00:00<00:00, 73622.27it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_asian_fb_AllPakistanDramaPageOfficial: 100%|██████████| 289/289 [00:00<00:00, 233465.69it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_asian_topindianactors: 100%|██████████| 386/386 [00:00<00:00, 286751.92it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_asian_wabfighters: 100%|██████████| 498/498 [00:00<00:00, 417502.18it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_black_GhanaFilmIndustry: 100%|██████████| 158/158 [00:00<00:00, 203594.48it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_black_kenya: 100%|██████████| 318/318 [00:00<00:00, 387616.59it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_classyfemale_images: 100%|██████████| 464/464 [00:00<00:00, 347156.09it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_mtv_images: 100%|██████████| 7229/7229 [00:00<00:00, 439658.71it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_usa: 100%|██████████| 24/24 [00:00<00:00, 79764.89it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_faces_withtext_cnnpolitics_images: 100%|██████████| 1783/1783 [00:00<00:00, 430092.25it/s]
#   gen_ai_detector_dataset/real_faces_multinational_130325/real_images_faces_and_others: 100%|██████████| 4322/4322 [00:00<00:00, 384535.70it/s]
#   gen_ai_detector_dataset/testset/testset_1: 100%|██████████| 6846/6846 [00:00<00:00, 300751.04it/s]
# ╔──────────────────────────────────────────────────────────────────────╗
# ║  STEP 2a — SCAN LOCAL DIR  [project: GAID-v11]                       ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Scanned         : /home/taiaburrahman/dataset_manager_pro/data/processed/v11_samples║
# ║  Saved to        : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/02.GAID-v11_local_scanned.csv║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Total images    : 886,356                                           ║
# ║  Label 0 (fake)  : 0                                                 ║
# ║  Label 1 (real)  : 0                                                 ║
# ║  Unknown label   : 0                                                 ║
# ║  Unique filenames : 881,576                                          ║
# ╚──────────────────────────────────────────────────────────────────────╝

# %% [markdown]
# ## Appendix — Re-run Comparison from Saved CSVs
#
# If you've already run Steps 1 & 2 in a previous session, load the saved CSVs directly:

# %%
# ── INPUT ──────────────────────────────────────────────────────────────────
# Paths auto-resolve from PROJECT_NAME — change only if loading from elsewhere
CSV_A = CSV_DIR / f"01.{Path(SOURCE_CSV).stem}_with_filename.csv"
CSV_B = CSV_DIR / f"02.{PROJECT_NAME}_local_scanned.csv"   # or 02.<PROJECT_NAME>_wasabi_scanned.csv
# ───────────────────────────────────────────────────────────────────────────

print(f"Project  : {PROJECT_NAME}")
print(f"CSV A    : {CSV_A}")
print(f"CSV B    : {CSV_B}\n")

results = compare_csvs(
    df_source   = CSV_A,
    df_scanned  = CSV_B,
    compare_col = "filename",
    prefix      = "03",
)
# Out:
# Project  : GAID-v11
# CSV A    : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/01.GAID_Dataset_v9_full_Train_with_filename.csv
# CSV B    : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/02.GAID-v11_local_scanned.csv
#
# Loading source  CSV …
# Loading scanned CSV …
# ╔──────────────────────────────────────────────────────────────────────╗
# ║  STEP 3 — CSV COMPARISON  [project: GAID-v11]                        ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Compare column       : 'filename'                                   ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  Source CSV           :    700,281 unique filenames                  ║
# ║  Scanned CSV          :    881,576 unique filenames                  ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  ✓  Common (both)     :    675,516                                   ║
# ║  ◀  Only in source    :     24,765                                   ║
# ║  ▶  Only in scanned   :    206,060                                   ║
# ╠──────────────────────────────────────────────────────────────────────╣
# ║  CSV dir              : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv║
# ║  Charts dir           : /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/charts║
# ║  common CSV           : 03.compare_common.csv                        ║
# ║  only_in_source CSV   : 03.compare_only_in_source.csv                ║
# ║  only_in_scanned CSV  : 03.compare_only_in_scanned.csv               ║
# ╚──────────────────────────────────────────────────────────────────────╝
#
# ── Sample: common files (first 10) ──
#                                                       filename labels
# 0                    real/0e35d3c709ef4123bb7b8cff23c885a4.jpg      1
# 1                                               real/12905.jpg      1
# 2                                                fake/1085.jpg      0
# 3                                         real/image_05650.png      1
# 4                    fake/d3c613a6d9574f55b3854643c5ca2374.jpg      0
# 5                                                fake/2839.jpg      0
# 7   Gen_samples_Grok3_180325/image - 2025-03-18T102548.813.jpg      0
# 8                    real/de2d9174de90417d9c7973a890ef7466.jpg      1
# 10                   fake/4cb2b6aec83a4968969fe57813deee04.jpg      0
# 11                   fake/0f84b73bab7642a5aa5ea38c47173bcd.jpg      0
# ── Sample: only in SOURCE csv (first 10) ──
#                                                               filename labels
# 6             code_gen_100325/5a3fcafb-5fe4-4781-8e76-16df69bc572d.jpg      0
# 9   Gen_samples_Gemini_190325/4a0bd30a-24d4-4d7c-9594-28c97d7a55ac.jpg      0
# 16            code_gen_100325/df70f4a5-872e-472d-96d4-51c91908be04.jpg      0
# 26  Gen_samples_Gemini_150325/143a4227-4133-4954-9413-e25863d3edff.jpg      0
# 27                             Gen_samples_Grok3_160325/image_6384.jpg      0
# 29  Gen_samples_Gemini_150325/ae8b3c84-e676-4dc0-a189-c5ad32374569.jpg      0
# 44                             Gen_samples_Grok3_160325/image_5114.jpg      0
# 45            code_gen_100325/b18adf02-277d-4dd6-8089-311e57930d48.jpg      0
# 47                             Gen_samples_Grok3_160325/image_3215.jpg      0
# 49   Gen_samples_Grok2_200325/2cecdead-f701-4b05-a29f-ff5e4ea1483a.jpg      0
# ── Sample: only in SCANNED csv (first 10) ──
#                                                              filename labels
# 0  Gen_samples_Gemini_100325/748ed959-f1bc-495f-8384-451d41bce327.jpg    NaN
# 1  Gen_samples_Gemini_100325/ff49695c-6842-4485-8bb1-f9f05b354f27.jpg    NaN
# 2  Gen_samples_Gemini_100325/d87f7bc7-3cfe-44a7-9f40-b82fb58ba33b.jpg    NaN
# 3  Gen_samples_Gemini_100325/9a1a2b40-47ce-46d9-a279-cf850e375d31.jpg    NaN
# 4  Gen_samples_Gemini_100325/a134088b-cff3-42f9-9b94-a49a7b054bc7.jpg    NaN
# 5  Gen_samples_Gemini_100325/c2488e70-85ac-4889-a36b-cdd6af439178.jpg    NaN
# 6  Gen_samples_Gemini_100325/892ad7df-2b3b-4e34-9b4e-5258eb8e5b30.jpg    NaN
# 7  Gen_samples_Gemini_100325/d4f45a0b-2f3f-492a-babe-5afcb92f733b.jpg    NaN
# 8  Gen_samples_Gemini_100325/001d87a0-2850-45ae-aa21-6e2f6076c7b9.jpg    NaN
# 9  Gen_samples_Gemini_100325/101a8b48-980e-48ce-918d-028677ac3b2a.jpg    NaN
#   Charts saved → /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/charts/03.compare_charts.png
#   Label breakdown saved → /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/charts/03.compare_label_breakdown.png

# %% [markdown]
# ---
# ## 9 — Missing Image Audit
#
# Cross-references every image in `SOURCE_CSV` and `VAL_CSV` against the files actually present in `IMAGE_SCAN_DIR` (matched by **filename**).
#
# Outputs per-split summaries and saves two CSVs:
#
# | File | Contents |
# |---|---|
# | `missing_images_train.csv` | Rows from Train CSV whose filename was **not found** locally |
# | `missing_images_val.csv` | Rows from Val CSV whose filename was **not found** locally |
#
# Each CSV contains: `image_path` (original), `labels`, `filename`, `source_folder`
#
# | Variable | Meaning |
# |---|---|
# | `LOCAL_DATA_ROOT` | Defaults to `IMAGE_SCAN_DIR` — the extracted local image directory |
# | `SAVE_MISSING_CSV` | `True` → write missing-image rows to `CSV_DIR` |
# | `SAVE_FOUND_CSV` | `True` → also write found-image rows (can be large) |

# %%
# ── INPUT ──────────────────────────────────────────────────────────────────
LOCAL_DATA_ROOT  = IMAGE_SCAN_DIR   # scanned/extracted local directory to match against
SAVE_MISSING_CSV = True             # save missing-image rows to CSV_DIR
SAVE_FOUND_CSV   = False            # also save found-image rows (can be large)
# ───────────────────────────────────────────────────────────────────────────

_csv_paths = {"Train": SOURCE_CSV, "Val": VAL_CSV}
_img_exts  = {".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tiff", ".tif"}

# ── Step 1: index all local filenames in IMAGE_SCAN_DIR ────────────────────
local_root = Path(LOCAL_DATA_ROOT)
print(f"Indexing local files in:\n  {local_root}\n  (this may take a moment…)")

if not local_root.exists():
    raise FileNotFoundError(f"LOCAL_DATA_ROOT not found: {local_root}")

# parent_folder/filename → full local path  (last-write wins on duplicates)
local_index: dict[str, Path] = {}
for f in local_root.rglob("*"):
    if f.is_file() and f.suffix.lower() in _img_exts:
        local_index[f"{f.parent.name}/{f.name}"] = f

print(f"  Indexed {len(local_index):,} local image files\n")

# ── Step 2: compare each CSV against the local index ──────────────────────
all_results = {}

for split_name, csv_path in _csv_paths.items():
    if csv_path is None:
        print(f"  {split_name}: skipped (path is None)\n")
        continue
    p = Path(csv_path)
    if not p.exists():
        print(f"  {split_name}: ✗ file not found → {p.name}\n")
        continue

    df = pd.read_csv(p, dtype=str, low_memory=False)
    df = df.dropna(subset=["image_path"]).reset_index(drop=True)

    # Derive filename as parent_folder/basename from the original image_path
    df["filename"] = df["image_path"].apply(_rel_name)

    # Match against local index
    df["local_path"] = df["filename"].map(
        lambda fn: str(local_index[fn]) if fn in local_index else ""
    )
    df["found_locally"] = df["local_path"] != ""

    df_found   = df[df["found_locally"]].copy()
    df_missing = df[~df["found_locally"]].copy()

    all_results[split_name] = {
        "found":   df_found,
        "missing": df_missing,
    }

    # ── Per-source breakdown of missing ────────────────────────────────────
    def _src_folder(path_str, depth=2):
        p = Path(str(path_str))
        for _ in range(depth):
            p = p.parent
        return p.name

    df_missing["source_folder"] = df_missing["image_path"].apply(_src_folder)
    src_counts = (
        df_missing.groupby("source_folder")
                  .size()
                  .sort_values(ascending=False)
                  .reset_index(name="missing_count")
    )

    # ── Print summary box ──────────────────────────────────────────────────
    W = 70
    sep = "─" * (W - 2)
    pct_miss = 100 * len(df_missing) / max(len(df), 1)
    pct_found = 100 * len(df_found)  / max(len(df), 1)

    print(f"╔{sep}╗")
    print(f"║  {(split_name.upper() + ' — IMAGE MATCH AUDIT  [' + p.name + ']')[:W-4]:<{W-4}}║")
    print(f"╠{sep}╣")
    print(f"║  Total in CSV          : {len(df):>10,}{'':21}║")
    print(f"║  ✓  Found locally      : {len(df_found):>10,}  ({pct_found:5.1f} %){'':8}║")
    print(f"║  ✗  Missing locally    : {len(df_missing):>10,}  ({pct_miss:5.1f} %){'':8}║")
    print(f"╠{sep}╣")
    print(f"║  {'MISSING — by source folder':<{W-4}}║")
    print(f"╠{sep}╣")
    for _, row in src_counts.iterrows():
        line = f"  ✗ {row['source_folder']}  ({row['missing_count']:,} images)"
        print(f"║  {line[:W-4]:<{W-4}}║")
    print(f"╚{sep}╝\n")

    # ── Save outputs ───────────────────────────────────────────────────────
    if SAVE_MISSING_CSV or SAVE_FOUND_CSV:
        out_dir = globals().get("CSV_DIR", Path("./csv"))
        out_dir.mkdir(parents=True, exist_ok=True)

    if SAVE_MISSING_CSV and len(df_missing):
        cols = ["image_path", "labels", "filename", "source_folder"]
        cols = [c for c in cols if c in df_missing.columns]
        out  = out_dir / f"missing_images_{split_name.lower()}.csv"
        df_missing[cols].to_csv(out, index=False)
        print(f"  ✗ Missing list saved  → {out}  ({len(df_missing):,} rows)")

    if SAVE_FOUND_CSV and len(df_found):
        cols = ["image_path", "labels", "filename", "local_path"]
        cols = [c for c in cols if c in df_found.columns]
        out  = out_dir / f"found_images_{split_name.lower()}.csv"
        df_found[cols].to_csv(out, index=False)
        print(f"  ✓ Found list saved    → {out}  ({len(df_found):,} rows)")

    print()
# Out:
# Indexing local files in:
#   /home/taiaburrahman/dataset_manager_pro/data/processed/v11_samples
#   (this may take a moment…)
#   Indexed 881,576 local image files
#
# ╔────────────────────────────────────────────────────────────────────╗
# ║  TRAIN — IMAGE MATCH AUDIT  [GAID_Dataset_v9_full_Train.csv]       ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║  Total in CSV          :    704,779                     ║
# ║  ✓  Found locally      :    680,014  ( 96.5 %)        ║
# ║  ✗  Missing locally    :     24,765  (  3.5 %)        ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║  MISSING — by source folder                                        ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║    ✗ fake  (20,449 images)                                         ║
# ║    ✗ Gen_samples_Gemini_100325  (4,316 images)                     ║
# ╚────────────────────────────────────────────────────────────────────╝
#
#   ✗ Missing list saved  → /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/missing_images_train.csv  (24,765 rows)
#
# ╔────────────────────────────────────────────────────────────────────╗
# ║  VAL — IMAGE MATCH AUDIT  [GAID_Dataset_v9_full_Val.csv]           ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║  Total in CSV          :     63,582                     ║
# ║  ✓  Found locally      :     62,786  ( 98.7 %)        ║
# ║  ✗  Missing locally    :        796  (  1.3 %)        ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║  MISSING — by source folder                                        ║
# ╠────────────────────────────────────────────────────────────────────╣
# ║    ✗ fake  (637 images)                                            ║
# ║    ✗ Gen_samples_Gemini_100325  (159 images)                       ║
# ╚────────────────────────────────────────────────────────────────────╝
#
#   ✗ Missing list saved  → /home/taiaburrahman/dataset_manager_pro/data/processed/GAID-v11/csv/missing_images_val.csv  (796 rows)

# %%
# Uses `all_results` from the previous cell (run Section 9 first).
from IPython.display import display, HTML
from pathlib import Path

def _src_folder(path_str, depth=2):
    p = Path(str(path_str))
    for _ in range(depth):
        p = p.parent
    return p.name

def _folder_segments(path_str, n=4):
    """Extract the last *n* directory segments from a file path."""
    parts = Path(str(path_str)).parent.parts
    return "/".join(parts[-n:]) if len(parts) >= n else "/".join(parts)

_out_dir = globals().get("CSV_DIR", Path("./csv"))
_out_dir.mkdir(parents=True, exist_ok=True)

for split_name, data in all_results.items():
    df_found   = data["found"]
    df_missing = data["missing"]

    if "source_folder" not in df_found.columns:
        df_found = df_found.copy()
        df_found["source_folder"] = df_found["image_path"].apply(_src_folder)
    if "source_folder" not in df_missing.columns:
        df_missing = df_missing.copy()
        df_missing["source_folder"] = df_missing["image_path"].apply(_src_folder)

    # Build mapping: source_folder → 4-segment folder path (from first occurrence)
    _all_df = pd.concat([df_found, df_missing], ignore_index=True)
    _all_df["_seg4"] = _all_df["image_path"].apply(_folder_segments)
    _seg4_map = _all_df.groupby("source_folder")["_seg4"].first().to_dict()

    found_counts   = df_found.groupby("source_folder").size()
    missing_counts = df_missing.groupby("source_folder").size()
    all_folders    = sorted(set(found_counts.index) | set(missing_counts.index))

    rows = []
    for folder in all_folders:
        avail = int(found_counts.get(folder, 0))
        miss  = int(missing_counts.get(folder, 0))
        total = avail + miss
        pct   = 100.0 * avail / total if total else 0
        status = "✓" if miss == 0 else ("⚠" if pct > 50 else "✗")
        rows.append({
            "status": status, "source_folder": folder,
            "folder_path": _seg4_map.get(folder, ""),
            "total": total, "available": avail, "missing": miss,
            "coverage_pct": round(pct, 1),
        })

    summary = pd.DataFrame(rows)

    # Save raw CSV (downloadable)
    csv_path = _out_dir / f"folder_summary_{split_name.lower()}.csv"
    summary.to_csv(csv_path, index=False)

    # Totals row
    t_total = summary["total"].sum()
    t_avail = summary["available"].sum()
    t_miss  = summary["missing"].sum()
    t_pct   = round(100.0 * t_avail / max(t_total, 1), 1)

    # Build styled HTML table
    def _bar(pct):
        color = "#27ae60" if pct == 100 else ("#f39c12" if pct > 50 else "#e74c3c")
        return (
            f'<div style="background:#eee;border-radius:4px;width:100%;height:16px">'
            f'<div style="background:{color};width:{pct}%;height:100%;border-radius:4px"></div>'
            f'</div>'
        )

    def _status_badge(s):
        colors = {"✓": "#27ae60", "⚠": "#f39c12", "✗": "#e74c3c"}
        bg = colors.get(s, "#999")
        return f'<span style="background:{bg};color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">{s}</span>'

    html_rows = ""
    for _, r in summary.iterrows():
        html_rows += (
            f"<tr>"
            f"<td style='text-align:center'>{_status_badge(r['status'])}</td>"
            f"<td style='padding-left:8px'>{r['source_folder']}</td>"
            f"<td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>{r['folder_path']}</td>"
            f"<td style='text-align:right'>{r['total']:,}</td>"
            f"<td style='text-align:right;color:#27ae60'>{r['available']:,}</td>"
            f"<td style='text-align:right;color:#e74c3c'>{r['missing']:,}</td>"
            f"<td style='text-align:right'>{r['coverage_pct']} %</td>"
            f"<td style='min-width:120px'>{_bar(r['coverage_pct'])}</td>"
            f"</tr>"
        )

    # Totals row
    html_rows += (
        f"<tr style='border-top:2px solid #333;font-weight:bold;background:#f5f5f5'>"
        f"<td></td>"
        f"<td style='padding-left:8px'>TOTAL</td>"
        f"<td></td>"
        f"<td style='text-align:right'>{t_total:,}</td>"
        f"<td style='text-align:right;color:#27ae60'>{t_avail:,}</td>"
        f"<td style='text-align:right;color:#e74c3c'>{t_miss:,}</td>"
        f"<td style='text-align:right'>{t_pct} %</td>"
        f"<td>{_bar(t_pct)}</td>"
        f"</tr>"
    )

    html = f"""
    <h3 style="margin-bottom:4px">{PROJECT_NAME} : {split_name.upper()} — Folder-wise Summary</h3>
    <table style="border-collapse:collapse;width:100%;font-size:13px;font-family:monospace">
    <thead>
      <tr style="background:#2c3e50;color:#fff;text-align:left">
        <th style="padding:6px 8px;text-align:center">Status</th>
        <th style="padding:6px 8px">Source Folder</th>
        <th style="padding:6px 8px;font-size:10px">Folder Path</th>
        <th style="padding:6px 8px;text-align:right">Total</th>
        <th style="padding:6px 8px;text-align:right">Available</th>
        <th style="padding:6px 8px;text-align:right">Missing</th>
        <th style="padding:6px 8px;text-align:right">Coverage</th>
        <th style="padding:6px 8px;min-width:120px"></th>
      </tr>
    </thead>
    <tbody>
      {html_rows}
    </tbody>
    </table>
    <p style="font-size:12px;color:#666;margin-top:6px">
      📥 CSV saved → <code>{csv_path}</code>
    </p>
    """
    display(HTML(html))
# Out:
#     <h3 style="margin-bottom:4px">GAID-v11 : TRAIN — Folder-wise Summary</h3>
#     <table style="border-collapse:collapse;width:100%;font-size:13px;font-family:monospace">
#     <thead>
#       <tr style="background:#2c3e50;color:#fff;text-align:left">
#         <th style="padding:6px 8px;text-align:center">Status</th>
#         <th style="padding:6px 8px">Source Folder</th>
#         <th style="padding:6px 8px;font-size:10px">Folder Path</th>
#         <th style="padding:6px 8px;text-align:right">Total</th>
#         <th style="padding:6px 8px;text-align:right">Available</th>
#         <th style="padding:6px 8px;text-align:right">Missing</th>
#         <th style="padding:6px 8px;text-align:right">Coverage</th>
#         <th style="padding:6px 8px;min-width:120px"></th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td style='text-align:center'><span style="background:#e74c3c;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✗</span></td><td style='padding-left:8px'>Gen_samples_Gemini_100325</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>Gen_samples/fake/Gen_samples_Gemini_100325/code_gen_100325</td><td style='text-align:right'>4,316</td><td style='text-align:right;color:#27ae60'>0</td><td style='text-align:right;color:#e74c3c'>4,316</td><td style='text-align:right'>0.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#e74c3c;width:0.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Shutterstock_Fake</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>NewDB/NewDB_Fake/Shutterstock_Fake/fake</td><td style='text-align:right'>29,742</td><td style='text-align:right;color:#27ae60'>29,742</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Shutterstock_Real</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>NewDB/NewDB_Real/Shutterstock_Real/real</td><td style='text-align:right'>22,953</td><td style='text-align:right;color:#27ae60'>22,953</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Test</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Test/Glacier</td><td style='text-align:right'>305</td><td style='text-align:right;color:#27ae60'>305</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Train</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Train/Mountain</td><td style='text-align:right'>5,864</td><td style='text-align:right;color:#27ae60'>5,864</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Val</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Val/Desert</td><td style='text-align:right'>834</td><td style='text-align:right;color:#27ae60'>834</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100 ...
#     <h3 style="margin-bottom:4px">GAID-v11 : VAL — Folder-wise Summary</h3>
#     <table style="border-collapse:collapse;width:100%;font-size:13px;font-family:monospace">
#     <thead>
#       <tr style="background:#2c3e50;color:#fff;text-align:left">
#         <th style="padding:6px 8px;text-align:center">Status</th>
#         <th style="padding:6px 8px">Source Folder</th>
#         <th style="padding:6px 8px;font-size:10px">Folder Path</th>
#         <th style="padding:6px 8px;text-align:right">Total</th>
#         <th style="padding:6px 8px;text-align:right">Available</th>
#         <th style="padding:6px 8px;text-align:right">Missing</th>
#         <th style="padding:6px 8px;text-align:right">Coverage</th>
#         <th style="padding:6px 8px;min-width:120px"></th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td style='text-align:center'><span style="background:#e74c3c;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✗</span></td><td style='padding-left:8px'>Gen_samples_Gemini_100325</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>Gen_samples/fake/Gen_samples_Gemini_100325/code_gen_100325</td><td style='text-align:right'>159</td><td style='text-align:right;color:#27ae60'>0</td><td style='text-align:right;color:#e74c3c'>159</td><td style='text-align:right'>0.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#e74c3c;width:0.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Shutterstock_Fake</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>NewDB/NewDB_Fake/Shutterstock_Fake/fake</td><td style='text-align:right'>904</td><td style='text-align:right;color:#27ae60'>904</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Shutterstock_Real</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>NewDB/NewDB_Real/Shutterstock_Real/real</td><td style='text-align:right'>710</td><td style='text-align:right;color:#27ae60'>710</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Test</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Test/Desert</td><td style='text-align:right'>7</td><td style='text-align:right;color:#27ae60'>7</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Train</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Train/Coast</td><td style='text-align:right'>178</td><td style='text-align:right;color:#27ae60'>178</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:120px'><div style="background:#eee;border-radius:4px;width:100%;height:16px"><div style="background:#27ae60;width:100.0%;height:100%;border-radius:4px"></div></div></td></tr><tr><td style='text-align:center'><span style="background:#27ae60;color:#fff;padding:2px 8px;border-radius:4px;font-weight:bold">✓</span></td><td style='padding-left:8px'>Val</td><td style='padding-left:8px;font-size:10px;color:#555;max-width:260px;word-break:break-all'>LandscapeRec12K/real/Val/Coast</td><td style='text-align:right'>32</td><td style='text-align:right;color:#27ae60'>32</td><td style='text-align:right;color:#e74c3c'>0</td><td style='text-align:right'>100.0 %</td><td style='min-width:1 ...

# %%
# ── Scan NEW_DATASET_DIR for images ───────────────────────────────────────
# Output → data/processed/<PROJECT_NAME>/csv/02.<PROJECT_NAME>_new_local_scanned.csv
df_new_scanned = scan_image_dir(
    scan_dir    = NEW_DATASET_DIR,
    output_name = f"{PROJECT_NAME}_new_local_scanned",
    prefix      = "02",
)

print(f"\nNew dataset root : {NEW_DATASET_DIR}")
print(f"Total images     : {len(df_new_scanned):,}")
print(f"Unique filenames : {df_new_scanned['filename'].nunique():,}")
print(f"Top folders      : {sorted(df_new_scanned['directory'].unique().tolist())}")
df_new_scanned.head()
# Out:
# Scanning /home/taiaburrahman/dataset_manager_pro/data/processed/v11 …
#   Sub-folders : []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 # ── Scan NEW_DATASET_DIR for images ───────────────────────────────────────
#       2 # Output → data/processed/<PROJECT_NAME>/csv/02.<PROJECT_NAME>_new_local_scanned.csv
# ----> 3 df_new_scanned = scan_image_dir(
#       4     scan_dir    = NEW_DATASET_DIR,
#       5     output_name = f"{PROJECT_NAME}_new_local_scanned",
#       6     prefix      = "02",
#       7 )
#       9 print(f"\nNew dataset root : {NEW_DATASET_DIR}")
#      10 print(f"Total images     : {len(df_new_scanned):,}")
#
# Cell In[15], line 137, in scan_image_dir(scan_dir, output_dir, output_name, prefix)
#     134 dest = out / (_pfx(prefix) + output_name + ".csv")
#     135 df.to_csv(dest, index=False)
# --> 137 label_counts = df["labels"].value_counts().to_dict()
#     138 print(_box([
#     139     f"STEP 2a — SCAN LOCAL DIR  [project: {_proj()}]", "---",
#     140     f"Scanned         : {root}",
#    (...)    147     f"Unique filenames : {df['filename'].nunique():,}",
#     148 ]))
#     149 return df
#
# File ~/dataset_manager_pro/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/dataset_manager_pro/.venv/lib/python3.11/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'labels'
